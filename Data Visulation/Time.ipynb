# %%
import pandas as pd
import pandas_datareader as pr

# %% [markdown]
# get_data_yahoo pandas_datareader in bir fonksiyonu. AAPL veriyi apple hisselerinden alacağımızı söylüyor. verinin adı yani
#
# start end bilgileriyle hangi tarihler arsındakş hisse bilgilerini isteğimizi belirttik

# %%
df=pr.get_data_yahoo("AAPL",start="2016-01-01", end="2019-08-25")
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2016-01-04  26.342501  25.500000  25.652500  26.337500  270597600.0  24.111498
# 2016-01-05  26.462500  25.602501  26.437500  25.677500  223164000.0  23.507280
# 2016-01-06  25.592501  24.967501  25.139999  25.174999  273829600.0  23.047251
# 2016-01-07  25.032499  24.107500  24.670000  24.112499  324377600.0  22.074551
# 2016-01-08  24.777500  24.190001  24.637501  24.240000  283192000.0  22.191277

# %%
kapanis=df["Close"]

# %%
kapanis.head()
# Out:
# Date
# 2016-01-04    26.337500
# 2016-01-05    25.677500
# 2016-01-06    25.174999
# 2016-01-07    24.112499
# 2016-01-08    24.240000
# Name: Close, dtype: float64

# %%
kapanis.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# burada plot() fonksitonu ile veriyi görselleştirdik
#
# baktığımızda sorun yok. ancak normalde time kısmında sorun olabiliyor. ordinal katagorik nominal gibi algıllıyordu sıralamada hata yapıyordu ya düzeltiyorduk
#
# şşimdi de zman olduğunda zaman olarak belirtmediğimizde hata olabiliyor.

# %%
df.index=pd.DatetimeIndex(kapanis.index)

# %% [markdown]
# ?neden index dedik
#
# data ya bakalım tarih kısımları aslında data frame in index i

# %%
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
kapanis.head()
# Out:
# Date
# 2016-01-04    26.337500
# 2016-01-05    25.677500
# 2016-01-06    25.174999
# 2016-01-07    24.112499
# 2016-01-08    24.240000
# Name: Close, dtype: float64

# %%
kapanis.plot()
# Out:
# <AxesSubplot: xlabel='Date'>
