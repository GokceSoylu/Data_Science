# %%
import pandas as pd
import seaborn as sns

# %%
data=sns.load_dataset("diamonds")
df=data.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df.cut
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
# 3          Premium
# 4             Good
#            ...
# 53935        Ideal
# 53936         Good
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: category
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
from pandas import CategoricalDtype

# %%
cut_ctg=["Fair","Good","Very Good","Premium","Ideal"]
df.cut=df.cut.astype(CategoricalDtype(ordered=True, categories=cut_ctg))

# %% [markdown]
# ## Grafikleştirelim :))
#
# sütün grafiği katagorik değişkenler için kullanılır
#
# data_frame["değişken_adi].value_counts().plot.barh()

# %%
df["cut"].value_counts().plot.barh()
# Out:
# <AxesSubplot: >

# %% [markdown]
# başlık ekelemek içim

# %%
df["cut"].value_counts().plot.barh().set_title("Cut Değişkeninin Sınıf Frekansları")
# Out:
# Text(0.5, 1.0, 'Cut Değişkeninin Sınıf Frekansları')

# %% [markdown]
# hocam gördüğünğz gibi yan yana destabn gibi kod çirkein gözüküuor. noktadan sonralı alt alta yazılabilir

# %%
(df["cut"]
    .value_counts()
    .plot.barh()
    .set_title("Cut DEğişkeninşn Sınıf Frekansları"));

# %% [markdown]
# ## pandas yerine veri görselleştimede seaborn daha çok kolayşık sağlar
#
# sns.barplot(x = "değişken_adi", y= data_frame.değişken_adi.index, data=data_frame)

# %%
sns.barplot(x = "cut", y=df.cut.index, data=df)
# Out:
# <AxesSubplot: xlabel='cut'>
