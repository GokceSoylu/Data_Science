# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset("tips")
tip=data.copy()
tip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# ## linear graph
#
# lmplot fonksiyonunu kullanıcaz. lm linera model

# %%
sns.lmplot(x="total_bill", y="tip", data=tip)

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tip)

# %% [markdown]
# grafiğe yeni değişke ekelylim col keyword ile

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", col="time", data=tip)

# %% [markdown]
# bir değişken daha ekleyelim row ile
#
# şuan cinsiyet değişkeni içn satırlara, time değikeni için sütuna bakrız
#
# cinsiyet ve zamanın, toplma hesap bahşis ilişkisine etkisne bakıyoruz

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", col="time", row="sex", data=tip)
