# %% [markdown]
# # Head Map
#
# ısı haritası: daha geniş perspektiften bakmayı sağlar
#
# zamana göre bakmak yada belirli periyotlarda tekrar eden olaylara bakmak için kullanılır
#
# sadece zaman için değil çok sınıflı katogorik değişken ve bunu belirli bir sayısal değişken açısından görselleştirmek istersek kullanılabilir

# %%
import pandas as pd
import  seaborn as sns
data=sns.load_dataset("flights")
fldt=data.copy()
fldt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %% [markdown]
# ### veri seti hikayesi
#
# passenger = yolcu
#
# yillara ve aylara yolcu sayısı verilmektedir

# %% [markdown]
# ### pivot
#
# head map düzgün  bir halde bekler veriyi. önce pivot_table kullanrak düzgün hal egetirmrliyiz.
#
# pd.pivot_table(data_fraame, index="değişken_adi", columns="değişke_adi)

# %%
fldt=pd.pivot_table(fldt,index="month",columns="year");

# %%
fldt
# Out:
#       passengers
# year        1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960
# month
# Jan          112  115  145  171  196  204  242  284  315  340  360  417
# Feb          118  126  150  180  196  188  233  277  301  318  342  391
# Mar          132  141  178  193  236  235  267  317  356  362  406  419
# Apr          129  135  163  181  235  227  269  313  348  348  396  461
# May          121  125  172  183  229  234  270  318  355  363  420  472
# Jun          135  149  178  218  243  264  315  374  422  435  472  535
# Jul          148  170  199  230  264  302  364  413  465  491  548  622
# Aug          148  170  199  242  272  293  347  405  467  505  559  606
# Sep          136  158  184  209  237  259  312  355  404  404  463  508
# Oct          119  133  162  191  211  229  274  306  347  359  407  461
# Nov          104  114  146  172  180  203  237  271  305  310  362  390
# Dec          118  140  166  194  201  229  278  306  336  337  405  432

# %%
sns.heatmap(fldt)
# Out:
# <AxesSubplot: xlabel='None-year', ylabel='month'>

# %%
sns.heatmap(fldt, annot=True)#sayıalrı ekledik
# Out:
# <AxesSubplot: xlabel='None-year', ylabel='month'>

# %%
sns.heatmap(fldt,annot=True, fmt="d")#düzgünleştirdik
# Out:
# <AxesSubplot: xlabel='None-year', ylabel='month'>

# %%
sns.heatmap(fldt, annot=True, fmt="d", linewidths=.3)#aralra boşluk ekledik
# Out:
# <AxesSubplot: xlabel='None-year', ylabel='month'>

# %%
#yandakı renk skalasının kaptmak içinde cbar=false yaparız ama kapatmak pek iyi değil. okunulruğu azaltır 
sns.heatmap(fldt, annot=True, fmt="d", linewidths=.3, cbar=False)
# Out:
# <AxesSubplot: xlabel='None-year', ylabel='month'>
